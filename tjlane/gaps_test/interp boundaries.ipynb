# %%
from odin import xray
from odin import structure

dtc = xray.load('ds1_jun2011.dtc')

# %%
img = random.randn(10,dtc.num_pixels) * 100 + 1000
ss = xray.Shotset(img, dtc)
r = ss.to_rings([2.67, 3.08], num_phi=3600)
# Out:
# 12:21:15 - Converting shotset to polar space (Rings)
# 12:21:15 - interpolating shot 1/10
# 12:21:15 - interpolating shot 2/10
# 12:21:15 - interpolating shot 3/10
# 12:21:15 - interpolating shot 4/10
# 12:21:15 - interpolating shot 5/10
# 12:21:15 - interpolating shot 6/10
# 12:21:15 - interpolating shot 7/10
# 12:21:15 - interpolating shot 8/10
# 12:21:15 - interpolating shot 9/10
# 12:21:16 - interpolating shot 10/10

# %%
figure(figsize=(15,7))
plot(r.polar_intensities[0,1,:])
plot(r.polar_mask[1,:].astype(np.int) * 1000, lw=1)
ylim([800,1200])
# Out:
# (800, 1200)
